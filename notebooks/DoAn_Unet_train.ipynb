# %% [markdown]
# <a href="https://colab.research.google.com/github/CallmeKoi/DeepL-Semantic-Segment/blob/main/DoAn_Unet_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lấy dataset từ repo trên github

# %%
# !git clone https://github.com/CallmeKoi/DeepL-Semantic-Segment.git
# Out:
# fatal: destination path 'DeepL-Semantic-Segment' already exists and is not an empty directory.

# %%
# @title Thêm đường dẫn tới repo để dùng custom module
# Cách này bị giới hạn trong phiên hiện tại
import sys

# append a new directory to sys.path
sys.path.append('/content/DeepL-Semantic-Segment')

# print the updated sys.path
print('Updated sys.path:', sys.path)
# Out:
# Updated sys.path: ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython', '/content/DeepL-Semantic-Segment']

# %%
# @title Import thư viện
import os
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# Import custom module
from dataset_util import DataLoader, preprocessing
from models.Unet_model import Unet

# %%
# @title File metadata.csv chứa một số thông tin liên quan tới dataset
metadata = pd.read_csv('/content/DeepL-Semantic-Segment/metadata.csv')
print(len(metadata))
metadata.groupby(['Purpose'])['Class'].value_counts()
# Out:
# 1000
# Purpose  Class
# test     bicycle        50
#          car            50
#          motorcycle     50
#          pedestrian     50
# train    bicycle       150
#          car           150
#          motorcycle    150
#          pedestrian    150
# valid    bicycle        50
#          car            50
#          motorcycle     50
#          pedestrian     50
# Name: Class, dtype: int64

# %%
# @title File class_label.csv chứa nhãn lớp
class_df = pd.read_csv('/content/DeepL-Semantic-Segment/class_label.csv')
class_label = pd.Series(class_df['class'].values,index=class_df.label).to_dict()
print(class_label)
# Out:
# {0: 'background', 1: 'car', 2: 'bicycle', 3: 'motorcycle', 4: 'pedestrian'}

# %% [markdown]
# ### Chuẩn bị dữ liệu

# %%
# Lấy dataset
dir_to_data = '/content/DeepL-Semantic-Segment/zoo_dataset'
dataloader = DataLoader(dir_to_data)

# Load phần ảnh cần dùng
x_train, y_train = dataloader.load('train',(224,224),shuffle=True)
x_valid, y_valid = dataloader.load('valid',(224,224),shuffle=True)

print('Train data shape:',x_train.shape)
print('Train label shape:',y_train.shape)
print('Valid data shape:',x_valid.shape)
print('Valid label shape:',y_valid.shape)

# Tiền xử lý ảnh
NCLASSES = len(class_label) # số lượng lớp
X_train, Y_train = preprocessing(x_train, y_train, NCLASSES)
X_valid, Y_valid = preprocessing(x_valid, y_valid, NCLASSES)
# Out:
# ('/content/DeepL-Semantic-Segment/zoo_dataset/train/00399.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00590.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00594.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00303.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00016.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00634.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00878.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00602.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00873.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00635.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00050.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00764.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00849.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00309.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00808.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00555.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00802.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00613.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00614.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00641.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00511.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00556.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00362.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00558.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00290.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00862.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00596.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00584.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00089.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00580.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00343.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00375.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00342.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00567.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00765.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00394.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00002.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00144.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00532.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00579.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00606.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00538.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00318.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00062.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00277.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00094.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00331.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00055.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00051.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00251.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00806.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00630.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00795.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00086.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00388.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00789.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00752.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00367.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00063.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00060.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00869.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00504.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/train/00293.jpg', '/content/DeepL-Semantic-Segme ...
# ('/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00399.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00590.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00594.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00303.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00016.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00634.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00878.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00602.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00873.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00635.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00050.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00764.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00849.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00309.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00808.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00555.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00802.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00613.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00614.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00641.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00511.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00556.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00362.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00558.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00290.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00862.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00596.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00584.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00089.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00580.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00343.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00375.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00342.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00567.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00765.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00394.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00002.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00144.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00532.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00579.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00606.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00538.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00318.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00062.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00277.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00094.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00331.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00055.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00051.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00251.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00806.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00630.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00795.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00086.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00388.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00789.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/train/00752.npy', '/content ...
# ('/content/DeepL-Semantic-Segment/zoo_dataset/valid/00926.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00673.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00911.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00912.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00691.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00154.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00669.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00676.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00937.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00904.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00690.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00411.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00153.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00674.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00935.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00185.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00905.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00408.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00927.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00917.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00182.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00170.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00163.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00189.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00196.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00438.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00415.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00903.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00945.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00172.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00686.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00899.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00692.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00666.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00443.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00434.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00160.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00187.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00181.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00934.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00950.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00430.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00176.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00682.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00653.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00180.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00920.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00186.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00679.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00413.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00664.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00441.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00900.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00946.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00184.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00655.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00948.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00425.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00431.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00908.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00697.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00925.jpg', '/content/DeepL-Semantic-Segment/zoo_dataset/valid/00177.jpg', '/content/DeepL-Semantic-Segme ...
# ('/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00926.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00673.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00911.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00912.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00691.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00154.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00669.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00676.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00937.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00904.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00690.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00411.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00153.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00674.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00935.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00185.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00905.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00408.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00927.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00917.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00182.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00170.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00163.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00189.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00196.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00438.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00415.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00903.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00945.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00172.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00686.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00899.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00692.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00666.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00443.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00434.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00160.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00187.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00181.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00934.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00950.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00430.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00176.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00682.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00653.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00180.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00920.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00186.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00679.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00413.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00664.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00441.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00900.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00946.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00184.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00655.npy', '/content/DeepL-Semantic-Segment/zoo_dataset/labels/valid/00948.npy', '/content ...
# Train data shape: (600, 224, 224, 3)
# Train label shape: (600, 224, 224)
# Valid data shape: (200, 224, 224, 3)
# Valid label shape: (200, 224, 224)
# (600, 224, 224, 1)
# Label data shape is: (600, 224, 224, 5)
# (200, 224, 224, 1)
# Label data shape is: (200, 224, 224, 5)

# %% [markdown]
# ### Huấn luyện mô hình Unet cổ điển

# %%
# Load model
input_shape = X_train.shape[1:]
'''
Mô hình Unet nhận vào các tham số bắt buộc: input_shape, output_classes
Tham số tùy chỉnh: dropout_rate
'''
model = Unet(input_shape,NCLASSES, dropout_rate=0.3)
model.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Main Input (InputLayer)     [(None, 224, 224, 3)]        0         []
#
#  En_1_conv1 (Conv2D)         (None, 224, 224, 64)         1792      ['Main Input[0][0]']
#
#  En_1_norm1 (BatchNormaliza  (None, 224, 224, 64)         256       ['En_1_conv1[0][0]']
#  tion)
#
#  En_1_act1 (Activation)      (None, 224, 224, 64)         0         ['En_1_norm1[0][0]']
#
#  En_1_conv2 (Conv2D)         (None, 224, 224, 64)         36928     ['En_1_act1[0][0]']
#
#  En_1_norm2 (BatchNormaliza  (None, 224, 224, 64)         256       ['En_1_conv2[0][0]']
#  tion)
#
#  En_1_act2 (Activation)      (None, 224, 224, 64)         0         ['En_1_norm2[0][0]']
#
#  En_1_pool (MaxPooling2D)    (None, 112, 112, 64)         0         ['En_1_act2[0][0]']
#
#  dropout (Dropout)           (None, 112, 112, 64)         0         ['En_1_pool[0][0]']
#
#  En_2_conv1 (Conv2D)         (None, 112, 112, 128)        73856     ['dropout[0][0]']
#
#  En_2_norm1 (BatchNormaliza  (None, 112, 112, 128)        512       ['En_2_conv1[0][0]']
#  tion)
#
#  En_2_act1 (Activation)      (None, 112, 112, 128)        0         ['En_2_norm1[0][0]']
#
#  En_2_conv2 (Conv2D)         (None, 112, 112, 128)        147584    ['En_2_act1[0][0]']
#
#  En_2_norm2 (BatchNormaliza  (None, 112, 112, 128)        512       ['En_2_conv2[0][0]']
#  tion)
#
#  En_2_act2 (Activation)      (None, 112, 112, 128)        0         ['En_2_norm2[0][0]']
#
#  En_2_pool (MaxPooling2D)    (None, 56, 56, 128)          0         ['En_2_act2[0][0]']
#
#  dropout_1 (Dropout)         (None, 56, 56, 128)          0         ['En_2_pool[0][0]']
#
#  En_3_conv1 (Conv2D)         (None, 56, 56, 256)          295168    ['dropout_1[0][0]']
#
#  En_3_norm1 (BatchNormaliza  (None, 56, 56, 256)          1024      ['En_3_conv1[0][0]']
#  tion)
#
#  En_3_act1 (Activation)      (None, 56, 56, 256)          0         ['En_3_norm1[0][0]']
#
#  En_3_conv2 (Conv2D)         (None, 56, 56, 256)          590080    ['En_3_act1[0][0]']
#
#  En_3_norm2 (BatchNormaliza  (None, 56, 56, 256)          1024      ['En_3_conv2[0][0]']
#  tion)
#
#  En_3_act2 (Activation)      (None, 56, 56, 256)          0         ['En_3_norm2[0][0]']
#
#  En_3_pool (MaxPooling2D)    (None, 28, 28, 256)          0         ['En_3_act2[0][0]']
#
#  dropout_2 (Dropout)         (None, 28, 28, 256)          0         ['En_3_pool[0][0]']
#
#  En_4_conv1 (Conv2D)         (None, 28, 28, 512)          1180160   ['dropout_2[0][0]']
#
#  En_4_norm1 (BatchNormaliza  (None, 28, 28, 512)          2048      ['En_4_conv1[0][0]']
#  tion)
#
#  En_4_act1 (Activation)      (None, 28, 28, 512)          0         ['En_4_norm1[0][0]']
#
#  En_4_conv2 (Conv2D)         (None, 28, 28, 512)          2359808   ['En_4_act1[0][0]']
#
#  En_4_norm2 (BatchNormaliza  (None, 28, 28, 512)          2048      ['En_4_conv2[0][0]']
#  tion)
#
#  En_4_act2 (Activation)      (None, 28, 28, 512)          0         ['En_4_norm2[0][0]']
#
#  En_4_pool (MaxPooling2D)    (None, 14, 14, 512)          0         ['En_4_act2[0][0]']
#
#  dropout_3 (Dropout)         (None, 14, 14, 512)          0         ['En_4_pool[0][0]']
#
#  Bottleneck_conv1 (Conv2D)   (None, 14, 14, 1024)         4719616   ['dropout_3[0][0]']
#
#  Bottleneck_norm1 (BatchNor  (None, 14, 14, 1024)         4096      ['Bottleneck_conv1[0][0]']
#  malization)
#
#  Bottleneck_act1 (Activatio  (None, 14, 14, 1024)         0         ['Bottleneck_norm1[0][0]']
#  n)
#
#  Bottleneck_conv2 (Conv2D)   (None, 14, 14, 1024)         9438208   ['Bottleneck_act1[0][0]']
#
#  Bottleneck_norm2 (BatchNor  (None, 14, 14, 1024)         4096      ['Bottleneck_conv2[0][0]']
#  malization)
#
#  Bottleneck_act2 (Activatio  (None, 14, 14, 1024)         0         ['Bottleneck_norm2[0][0]']
#  n)
#
#  De_1_conv (Conv2DTranspose  (None, 28, 28, 512)          2097664   ['Bottleneck_act2[0][0]']
#  )
#
#  De_1_cat (Concatenate)      (None, 28, 28, 1024)         0         ['De_1_conv[0][0]',
#                                                                      'En_4_act2[0][0]']
#
#  dropout_4 (Dropout)         (None, 28, 28, 1024)         0         ['De_1_cat[0][0]']
#
#  De_1_conv1 (Conv2D)         (None, 28, 28, 512)          4719104   ['dropout_4[0][0]']
#
#  De_1_norm1 (BatchNormaliza  (None, 28, 28, 512)          2048      ['De_1_conv1[0][0]']
#  tion)
#
#  De_1_act1 (Activation)      (None, 28, 28, 512)          0         ['De_1_norm1[0][0]']
#
#  De_1_conv2 (Conv2D)         (None, 28, 28, 512)          2359808   ['De_1_act1[0][0]']
#
#  De_1_norm2 (BatchNormaliza  (None, 28, 28, 512)          2048      ['De_1_conv2[0][0]']
#  tion)
#
#  De_1_act2 (Activation)      (None, 28, 28, 512)          0         ['De_1_norm2[0][0]']
#
#  De_2_conv (Conv2DTranspose  (None, 56, 56, 256)          524544    ['De_1_act2[0][0]']
#  )
#
#  De_2_cat (Concatenate)      (None, 56, 56, 512)          0         ['De_2_conv[0][0]',
#                                                                      'En_3_act2[0][0]']
#
#  dropout_5 (Dropout)         (None, 56, 56, 512)          0         ['De_2_cat[0][0]']
#
#  De_2_conv1 (Conv2D)         (None, 56, 56, 256)          1179904   ['dropout_5[0][0]']
#
#  De_2_norm1 (BatchNormaliza  (None, 56, 56, 256)          1024      ['De_2_conv1[0][0]']
#  tion)
#
#  De_2_act1 (Activation)      (None, 56, 56, 256)          0         ['De_2_norm1[0][0]']
#
#  De_2_conv2 (Conv2D)         (None, 56, 56, 256)          590080    ['De_2_act1[0][0]']
#
#  De_2_norm2 (BatchNormaliza  (None, 56, 56, 256)          1024      ['De_2_conv2[0][0]']
#  tion)
#
#  De_2_act2 (Activation)      (None, 56, 56, 256)          0         ['De_2_norm2[0][0]']
#
#  De_3_conv (Conv2DTranspose  (None, 112, 112, 128)        131200    ['De_2_act2[0][0]']
#  )
#
#  De_3_cat (Concatenate)      (None, 112, 112, 256)        0         ['De_3_conv[0][0]',
#                                                                      'En_2_act2[0][0]']
#
#  dropout_6 (Dropout)         (None, 112, 112, 256)        0         ['De_3_cat[0][0]']
#
#  De_3_conv1 (Conv2D)         (None, 112, 112, 128)        295040    ['dropout_6[0][0]']
#
#  De_3_norm1 (BatchNormaliza  (None, 112, 112, 128)        512       ['De_3_conv1[0][0]']
#  tion)
#
#  De_3_act1 (Activation)      (None, 112, 112, 128)        0         ['De_3_norm1[0][0]']
#
#  De_3_conv2 (Conv2D)         (None, 112, 112, 128)        147584    ['De_3_act1[0][0]']
#
#  De_3_norm2 (BatchNormaliza  (None, 112, 112, 128)        512       ['De_3_conv2[0][0]']
#  tion)
#
#  De_3_act2 (Activation)      (None, 112, 112, 128)        0         ['De_3_norm2[0][0]']
#
#  De_4_conv (Conv2DTranspose  (None, 224, 224, 64)         32832     ['De_3_act2[0][0]']
#  )
#
#  De_4_cat (Concatenate)      (None, 224, 224, 128)        0         ['De_4_conv[0][0]',
#                                                                      'En_1_act2[0][0]']
#
#  dropout_7 (Dropout)         (None, 224, 224, 128)        0         ['De_4_cat[0][0]']
#
#  De_4_conv1 (Conv2D)         (None, 224, 224, 64)         73792     ['dropout_7[0][0]']
#
#  De_4_norm1 (BatchNormaliza  (None, 224, 224, 64)         256       ['De_4_conv1[0][0]']
#  tion)
#
#  De_4_act1 (Activation)      (None, 224, 224, 64)         0         ['De_4_norm1[0][0]']
#
#  De_4_conv2 (Conv2D)         (None, 224, 224, 64)         36928     ['De_4_act1[0][0]']
#
#  De_4_norm2 (BatchNormaliza  (None, 224, 224, 64)         256       ['De_4_conv2[0][0]']
#  tion)
#
#  De_4_act2 (Activation)      (None, 224, 224, 64)         0         ['De_4_norm2[0][0]']
#
#  conv2d (Conv2D)             (None, 224, 224, 5)          325       ['De_4_act2[0][0]']
#
# ==================================================================================================
# Total params: 31055557 (118.47 MB)
# Trainable params: 31043781 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________

# %%
# Chuyển dữ liệu về format tf.data

def tf_data(X_train, Y_train, X_val, Y_val, batch_size):
    train_ds = tf.data.Dataset.from_tensor_slices((X_train,
                                                   Y_train)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val,
                                                 Y_val)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

# %%
# Tinh chỉnh siêu tham số
batch_size = 16
epochs = 20

# Callback
cb = [EarlyStopping(monitor='val_loss', patience=5,
                    restore_best_weights=True)]

train_ds, val_ds = tf_data(X_train, Y_train, X_valid, Y_valid, batch_size)

H = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = epochs, callbacks = cb
)

# Save model
save_dir = os.path.join(os.getcwd(), 'trained_models')
if (not os.path.exists(save_dir)):
  os.makedirs(save_dir)

save_path = os.path.join(save_dir,'unet.best_model.keras')
model.save(save_path)
# Out:
# Epoch 1/20
# 38/38 [==============================] - 100s 1s/step - loss: 1.1900 - accuracy: 0.7286 - val_loss: 34216.3984 - val_accuracy: 0.0720
# Epoch 2/20
# 38/38 [==============================] - 35s 915ms/step - loss: 0.5894 - accuracy: 0.8682 - val_loss: 0.8305 - val_accuracy: 0.8160
# Epoch 3/20
# 38/38 [==============================] - 35s 930ms/step - loss: 0.5268 - accuracy: 0.8696 - val_loss: 0.6895 - val_accuracy: 0.8558
# Epoch 4/20
# 38/38 [==============================] - 36s 938ms/step - loss: 0.5123 - accuracy: 0.8698 - val_loss: 0.5986 - val_accuracy: 0.8558
# Epoch 5/20
# 38/38 [==============================] - 36s 942ms/step - loss: 0.4996 - accuracy: 0.8696 - val_loss: 0.5920 - val_accuracy: 0.8558
# Epoch 6/20
# 38/38 [==============================] - 36s 953ms/step - loss: 0.4903 - accuracy: 0.8701 - val_loss: 0.5752 - val_accuracy: 0.8558
# Epoch 7/20
# 38/38 [==============================] - 36s 957ms/step - loss: 0.4792 - accuracy: 0.8702 - val_loss: 0.5647 - val_accuracy: 0.8558
# Epoch 8/20
# 38/38 [==============================] - 36s 958ms/step - loss: 0.4711 - accuracy: 0.8702 - val_loss: 0.7152 - val_accuracy: 0.8482
# Epoch 9/20
# 38/38 [==============================] - 36s 961ms/step - loss: 0.4647 - accuracy: 0.8702 - val_loss: 0.5739 - val_accuracy: 0.8558
# Epoch 10/20
# 38/38 [==============================] - 37s 963ms/step - loss: 0.4564 - accuracy: 0.8701 - val_loss: 0.7633 - val_accuracy: 0.8338
# Epoch 11/20
# 38/38 [==============================] - 36s 957ms/step - loss: 0.4483 - accuracy: 0.8700 - val_loss: 0.5694 - val_accuracy: 0.8528
# Epoch 12/20
# 38/38 [==============================] - 37s 967ms/step - loss: 0.4424 - accuracy: 0.8701 - val_loss: 0.5960 - val_accuracy: 0.8299

# %%
# @title In đường cong học tập
print(H.history.keys())
plt.figure()
pd.DataFrame(H.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
# plt.plot(H.history['accuracy'], label="train_acc")
# plt.plot(H.history['val_accuracy'], label="val_acc")
# plt.plot(H.history['loss'], label = "train_loss")
# plt.plot(H.history['val_loss'], label = "val_loss")
plt.title('Training Loss and Accuracy')
plt.ylabel('Loss/Accuracy')
plt.xlabel('Epoch #')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31b770a2f973> in <cell line: 2>()
#       1 # @title In đường cong học tập
# ----> 2 print(H.history.keys())
#       3 plt.figure()
#       4 pd.DataFrame(H.history).plot(figsize=(8,5))
#       5 plt.grid(True)
#
# NameError: name 'H' is not defined
